# %% [markdown]
# <a href="https://colab.research.google.com/github/elusivemansiv/python-basics-with-Google-Colab/blob/main/PythonPractice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Variables & Data Types

# %%
name = "Mansib"
age = 25
department ="CS"
Bsc_CGPA = 3.60
print(name)
print(age)
print(department)
print(Bsc_CGPA)
# Out:
# Mansib
# 25
# CS
# 3.6

# %%
type(name)
# Out:
# str

# %%
type(age)
# Out:
# int

# %%
type(Bsc_CGPA)
# Out:
# float

# %% [markdown]
# Lists

# %%
list = []

# %%
list.append("Microsoft")
list.append("Android")

# %%
print(list)
# Out:
# ['Microsoft', 'Microsoft', 'Android']

# %%
list.append("Windows")
list.append("Ios")
list.append("Android")

# %%
print(list)
# Out:
# ['Microsoft', 'Microsoft', 'Android', 'Windows', 'Ios', 'Android']

# %%
for operatingsystem in list:
  print(f"The OS collections {list}")
# Out:
# The OS collections ['Microsoft', 'Microsoft', 'Android', 'Windows', 'Ios', 'Android']
# The OS collections ['Microsoft', 'Microsoft', 'Android', 'Windows', 'Ios', 'Android']
# The OS collections ['Microsoft', 'Microsoft', 'Android', 'Windows', 'Ios', 'Android']
# The OS collections ['Microsoft', 'Microsoft', 'Android', 'Windows', 'Ios', 'Android']
# The OS collections ['Microsoft', 'Microsoft', 'Android', 'Windows', 'Ios', 'Android']
# The OS collections ['Microsoft', 'Microsoft', 'Android', 'Windows', 'Ios', 'Android']

# %% [markdown]
# lists & for loop

# %%
from random import choices

# %%
games = ["Battlefield", "Grand Theft Auto", "Call of Duty", "Need For Speed"]
games_list =[]
for _ in range(3):
   games_list.append(choices(games))
print(f"I enjoyed Video Games: {games}")
# Out:
# I enjoyed Video Games: ['Battlefield', 'Grand Theft Auto', 'Call of Duty', 'Need For Speed']

# %%
ls
# Out:
# sample_data/

# %% [markdown]
# Arithmetic Operation

# %%
x= 5
y= 7
sum= x+y
sub= x-y
mul= x*y
div= x/y
print("X is :",x)
print("Y is: ", y)
print(f"The Result is {sum}")
print(f"The Result is {sub}")
print(f"The Result is {mul}")
print(f"The Result is {div}")
# Out:
# X is : 5
# Y is:  7
# The Result is 12
# The Result is -2
# The Result is 35
# The Result is 0.7142857142857143

# %%
a = 5
b = a ** 2
c = a ** 3

print(a)
print(b)
print(c)
# Out:
# 5
# 25
# 125

# %% [markdown]
# Condition

# %%
print("Wellcome To Movies")
age = int(input("Enter you Age: "))

if age < 18:
  print("You are not eligible to watch this movie")
elif age >=50:
  print("You are too old for this movie")
else:
  print("Enjoy!!!!!!")
# Out:
# Wellcome To Movies
# Enter you Age: 25
# Enjoy!!!!!!
